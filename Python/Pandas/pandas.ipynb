# %%
import pandas as pd

# %%
edades=[60,57,36,65,27,42,45,45,87,60]
nombres=['Marcelo','Rosana','Pablo','Diego','Micaela','Gabriela','Alejandro','Jose','Felipe','Jose Pablo']

# %%
# creo un dataframe y le paso las series, y lo que quiero que vaya como index.
serie=pd.Series(edades, index=nombres)
serie
# Out:
# Marcelo       60
# Rosana        57
# Pablo         36
# Diego         65
# Micaela       27
# Gabriela      42
# Alejandro     45
# Jose          45
# Felipe        87
# Jose Pablo    60
# dtype: int64

# %%
# primeras 5 entradas
serie.head()
# Out:
# Marcelo    60
# Rosana     57
# Pablo      36
# Diego      65
# Micaela    27
# dtype: int64

# %%
serie.tail()
# Out:
# Gabriela      42
# Alejandro     45
# Jose          45
# Felipe        87
# Jose Pablo    85
# dtype: int64

# %%
# valor minimo
serie.min()
# Out:
# 27

# %%
#valor max
serie.max()
# Out:
# 87

# %%
# promedio
serie.mean()
# Out:
# 54.9

# %%
# valor de la serie en la posicion numero 2, (indice 2)
serie[1]
# Out:
# 57

# %%
# obtener cuando el valor es igual a 60 (devuelve valores true o false.)
# Filtros.
serie==60
# Out:
# Marcelo        True
# Rosana        False
# Pablo         False
# Diego         False
# Micaela       False
# Gabriela      False
# Alejandro     False
# Jose          False
# Felipe        False
# Jose Pablo     True
# dtype: bool

# %%
# podemos usar el filtro de la anterior
# devuelve el df cuando coindicen esos valores.
serie[serie==60]
# Out:
# Marcelo       60
# Jose Pablo    60
# dtype: int64

# %%
df=pd.read_csv("./final_data.csv")
df
# Out:
#                                           player                      team  \
# 0             /david-de-gea/profil/spieler/59377         Manchester United
# 1            /jack-butland/profil/spieler/128899         Manchester United
# 2               /tom-heaton/profil/spieler/34130         Manchester United
# 3       /lisandro-martinez/profil/spieler/480762         Manchester United
# 4          /raphael-varane/profil/spieler/164770         Manchester United
# ...                                          ...                       ...
# 10749       /aidan-simmons/profil/spieler/867763  Western Sydney Wanderers
# 10750        /kusini-yengi/profil/spieler/708099  Western Sydney Wanderers
# 10751    /nathanael-blair/profil/spieler/1023268  Western Sydney Wanderers
# 10752    /zachary-sapsford/profil/spieler/703657  Western Sydney Wanderers
# 10753  /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers
#
# ...

# %%
df.head()
# Out:
#                                                        team  \
# player
# /david-de-gea/profil/spieler/59377        Manchester United
# /jack-butland/profil/spieler/128899       Manchester United
# /tom-heaton/profil/spieler/34130          Manchester United
# /lisandro-martinez/profil/spieler/480762  Manchester United
# /raphael-varane/profil/spieler/164770     Manchester United
#
#                                                        name  \
# player
# /david-de-gea/profil/spieler/59377             David de Gea
# /jack-butland/profil/spieler/128899            Jack Butland
# /tom-heaton/profil/spieler/34130                 Tom Heaton
# /lisandro-martinez/profil/spieler/480762  Lisandro Martínez
# /raphael-varane/profil/spieler/164770        Raphaël Varane
#
#                                                       position  height   age  \
# player
# /david-de-gea/profil/spieler/59377                  Goalkeeper   189.0  32.0
# ...

# %%
# filtro por columna
df[['team']]
# Out:
#                                                                team
# player
# /david-de-gea/profil/spieler/59377                Manchester United
# /jack-butland/profil/spieler/128899               Manchester United
# /tom-heaton/profil/spieler/34130                  Manchester United
# /lisandro-martinez/profil/spieler/480762          Manchester United
# /raphael-varane/profil/spieler/164770             Manchester United
# ...                                                             ...
# /aidan-simmons/profil/spieler/867763       Western Sydney Wanderers
# /kusini-yengi/profil/spieler/708099        Western Sydney Wanderers
# /nathanael-blair/profil/spieler/1023268    Western Sydney Wanderers
# /zachary-sapsford/profil/spieler/703657    Western Sydney Wanderers
# /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers
#
# [10754 rows x 1 columns]

# %%
# filtro por dos o mas columnas
df[['team','age']]
# Out:
#                                                                team   age
# player
# /david-de-gea/profil/spieler/59377                Manchester United  32.0
# /jack-butland/profil/spieler/128899               Manchester United  30.0
# /tom-heaton/profil/spieler/34130                  Manchester United  37.0
# /lisandro-martinez/profil/spieler/480762          Manchester United  25.0
# /raphael-varane/profil/spieler/164770             Manchester United  30.0
# ...                                                             ...   ...
# /aidan-simmons/profil/spieler/867763       Western Sydney Wanderers  20.0
# /kusini-yengi/profil/spieler/708099        Western Sydney Wanderers  24.0
# /nathanael-blair/profil/spieler/1023268    Western Sydney Wanderers  19.0
# /zachary-sapsford/profil/spieler/703657    Western Sydney Wanderers  20.0
# /alexander-badolato/profil/spieler/957230  Western Sydney Wanderers  18.0
#
# [10754 rows x 2 columns]

# %%
# filtrar por filas
# creo un df  con las columnas que quiero filtrar y los valores a buscar

racing=df[df['team']=='Racing Club']
Boca=df[df['team']=='Real Madrid']
#racing
Boca
# Out:
#                                                    team                 name  \
# player
# /thibaut-courtois/profil/spieler/108390     Real Madrid     Thibaut Courtois
# /andriy-lunin/profil/spieler/404839         Real Madrid         Andriy Lunin
# /eder-militao/profil/spieler/401530         Real Madrid         Éder Militão
# /david-alaba/profil/spieler/59016           Real Madrid          David Alaba
# /antonio-rudiger/profil/spieler/86202       Real Madrid      Antonio Rüdiger
# /nacho-fernandez/profil/spieler/58884       Real Madrid      Nacho Fernández
# /jesus-vallejo/profil/spieler/251896        Real Madrid        Jesús Vallejo
# /ferland-mendy/profil/spieler/291417        Real Madrid        Ferland Mendy
# /daniel-carvajal/profil/spieler/138927      Real Madrid      Daniel Carvajal
# /lucas-vazquez/profil/spieler/221316        Real Madrid        Lucas Vázquez
# /alvaro-odriozola/profil/spieler/280730     Real Madrid     Álvaro Odriozola
# ...

# %%
# buscar coincidencias y filtros 

filtro=df['team'].str.contains('Boca')
racing=df[filtro]
racing
# Out:
#                                          player             team  \
# 8208        /sergio-romero/profil/spieler/30690  CA Boca Juniors
# 8209        /leandro-brey/profil/spieler/982633  CA Boca Juniors
# 8210         /javier-garcia/profil/spieler/7966  CA Boca Juniors
# 8211       /nicolas-figal/profil/spieler/334055  CA Boca Juniors
# 8212        /bruno-valdez/profil/spieler/335768  CA Boca Juniors
# 8213          /marcos-rojo/profil/spieler/93176  CA Boca Juniors
# 8214   /nicolas-valentini/profil/spieler/860992  CA Boca Juniors
# 8215      /gabriel-aranda/profil/spieler/911962  CA Boca Juniors
# 8216    /facundo-roncaglia/profil/spieler/61546  CA Boca Juniors
# 8217         /frank-fabra/profil/spieler/156561  CA Boca Juniors
# 8218      /valentin-barco/profil/spieler/849410  CA Boca Juniors
# 8219      /agustin-sandez/profil/spieler/847023  CA Boca Juniors
# 8220    /marcelo-weigandt/profil/spieler/491690  CA Boca Juniors
# ...

# %%
#filtrar por edad
mayoresEdad=df[df['age'] > 21]
mayoresEdad
# Out:
#                                          player                      team  \
# 0            /david-de-gea/profil/spieler/59377         Manchester United
# 1           /jack-butland/profil/spieler/128899         Manchester United
# 2              /tom-heaton/profil/spieler/34130         Manchester United
# 3      /lisandro-martinez/profil/spieler/480762         Manchester United
# 4         /raphael-varane/profil/spieler/164770         Manchester United
# ...                                         ...                       ...
# 10745   /brandon-borrello/profil/spieler/293592  Western Sydney Wanderers
# 10746       /amor-layouni/profil/spieler/208880  Western Sydney Wanderers
# 10747      /yeni-ngbakoto/profil/spieler/111053  Western Sydney Wanderers
# 10748   /jarrod-carluccio/profil/spieler/749273  Western Sydney Wanderers
# 10750       /kusini-yengi/profil/spieler/708099  Western Sydney Wanderers
#
#                     name               position  height   age  appearance  \
# ...

# %%
# jugadores que hacen goles y tambien asistencias
df[['goals', 'assists']]
# Out:
#           goals   assists
# 0      0.000000  0.000000
# 1      0.000000  0.000000
# 2      0.000000  0.000000
# 3      0.028090  0.056180
# 4      0.017889  0.017889
# ...         ...       ...
# 10749  0.175953  0.087977
# 10750  0.372671  0.186335
# 10751  0.375000  0.000000
# 10752  0.312139  0.104046
# 10753  0.000000  0.000000
#
# [10754 rows x 2 columns]

# %%
asistencias_goles= df.query('goals > 0 and assists > 0')
asistencias_goles[['name','team','position']]
# Out:
#                     name                      team               position
# 3      Lisandro Martínez         Manchester United   Defender Centre-Back
# 4         Raphaël Varane         Manchester United   Defender Centre-Back
# 9              Luke Shaw         Manchester United     Defender Left-Back
# 10        Tyrell Malacia         Manchester United     Defender Left-Back
# 12           Diogo Dalot         Manchester United    Defender Right-Back
# ...                  ...                       ...                    ...
# 10746       Amor Layouni  Western Sydney Wanderers     Attack-RightWinger
# 10747     Yeni N'Gbakoto  Western Sydney Wanderers     Attack-RightWinger
# 10749      Aidan Simmons  Western Sydney Wanderers     Attack-RightWinger
# 10750       Kusini Yengi  Western Sydney Wanderers  Attack Centre-Forward
# 10752   Zachary Sapsford  Western Sydney Wanderers  Attack Centre-Forward
#
# [5171 rows x 3 columns]
