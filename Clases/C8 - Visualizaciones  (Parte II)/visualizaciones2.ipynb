# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib as mlp
import seaborn as sns

# %%
pinguino= sns.load_dataset("penguins")
pinguino
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
pinguino.hist(bins=30)
# Out:
# array([[<Axes: title={'center': 'bill_length_mm'}>,
#         <Axes: title={'center': 'bill_depth_mm'}>],
#        [<Axes: title={'center': 'flipper_length_mm'}>,
#         <Axes: title={'center': 'body_mass_g'}>]], dtype=object)

# %%
pinguino['flipper_length_mm'].hist(bins=10)
# Out:
# <Axes: >

# %%
pinguino['flipper_length_mm'].hist(bins=30)
# Out:
# <Axes: >

# %%
# creo un histplot, le paso el df
# al eje x le paso el tamaño del pico, muestro speciies (hue), bins 12
# multiple por stack (las barras se apilen una arriba de la otra.)
sns.histplot(data=pinguino, x="flipper_length_mm", hue="species", multiple="stack", bins=12)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
# igual que el anterior, pero las barras se agrupan una del lado de la otra.
sns.histplot(data=pinguino, x="flipper_length_mm", hue="species", multiple="dodge", bins=12)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
# Axes-level
# el hue lo muestro por island
sns.histplot(data=pinguino, x="flipper_length_mm", hue="island", multiple="stack", bins=12)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
# Axes-level
# mismo ejemplo, ahora barra una del lado de la otra.
sns.histplot(data=pinguino, x="flipper_length_mm", hue="island", multiple="dodge", bins=12)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=pinguino, x="island", hue="species", multiple="stack")
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %%
sns.histplot(data=pinguino, x="flipper_length_mm", hue="island", alpha=0.3)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
# MULITPLE (CUANDO PONGO COLUMNAS)
# muestra x graaficos por cantidad de species ( 3 en este caso)
sns.displot(data=pinguino, x="flipper_length_mm", hue="species", col="species")

# %%
pinguino.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.boxplot(data=pinguino[['bill_length_mm', 'bill_depth_mm','flipper_length_mm']])
# Out:
# <Axes: >

# %%
# crea figura con ejes (graficos)(axs)
# gridspec --> usa un dict, para darle dif anchos a las columnas.
f, axs=plt.subplots(1,2, figsize=(8,4), gridspec_kw=dict(width_ratios=[4,3]))


# creo grafico de dispersion, paso ejex e y , con hue , y ocupa el primer eje
sns.scatterplot(data=pinguino, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])

# creo un histograma, paso parametors, shrink (separacion de barras), alpha (opacidad) sin leyenda,
# y que vaya a la posicion dos
sns.histplot(data=pinguino, x="species",hue="species",shrink=0.8, alpha=0.8, legend=False, ax=axs[1])

# ajusta diseños. para evitar superposiciones.
f.tight_layout()

# %%
propinas=sns.load_dataset("tips")
propinas
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# creo una grafico relacional(relplot, y paso los parametros, )
grafico=sns.relplot(data=propinas, x="total_bill", y="tip")

# %%
vuelos=sns.load_dataset("flights")
vuelos.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# creo un df, que guarde cunando el mes sea igual a abril
mis_vuelos=vuelos.query("month=='Apr'")

# grafico de linea, y le paso el df, x = año, y= cantidad de pasajeros.
sns.lineplot(data=mis_vuelos, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
mis_vuelos
# Out:
#      year month  passengers
# 3    1949   Apr         129
# 15   1950   Apr         135
# 27   1951   Apr         163
# 39   1952   Apr         181
# 51   1953   Apr         235
# 63   1954   Apr         227
# 75   1955   Apr         269
# 87   1956   Apr         313
# 99   1957   Apr         348
# 111  1958   Apr         348
# 123  1959   Apr         396
# 135  1960   Apr         461

# %%
# creo un df, con la funcion pivot
# 1er parametro va como fila
# 2do como columna
# 3ero como valor
vuelos_wide=vuelos.pivot("year","month", "passengers")
vuelos_wide
sns.lineplot(data=vuelos_wide)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_14380\291104508.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   vuelos_wide=vuelos.pivot("year","month", "passengers")
# <Axes: xlabel='year'>

# %%
propinas
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=propinas, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=propinas, x="total_bill",y="tip", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_theme(style="whitegrid")
ax=sns.barplot(data=propinas, x="day", y="total_bill")

# %%
sns.barplot(data=propinas, x="day", y="total_bill", hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#histograma

sns.histplot(data=pinguino, x="flipper_length_mm")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=pinguino, x="flipper_length_mm", hue="species", alpha=0.3)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(x=propinas["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(data=propinas, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df_lluvias=pd.read_csv("./pune_1965_to_2002.csv", index_col=0)
df_lluvias
# Out:
#         Jan    Feb    Mar     Apr     May      Jun      Jul      Aug      Sep  \
# Year
# 1965  0.029  0.069  0.000  21.667  17.859  102.111  606.071  402.521   69.511
# 1966  0.905  0.000  0.000   2.981  63.008   94.088  481.942   59.386  150.624
# 1967  0.248  3.390  1.320  13.482  11.116  251.314  780.006  181.069  183.757
# 1968  0.318  3.035  1.704  23.307   7.441  179.872  379.354  171.979  219.884
# 1969  0.248  2.524  0.334   4.569   6.213  393.682  678.354  397.335  205.413
# 1970  0.070  0.000  0.001  16.218  68.036  300.546  330.502  283.476  158.640
# 1971  0.000  0.000  0.000   0.812  57.691  297.187  122.195  372.693  286.056
# 1972  0.000  0.029  0.000   5.982  19.101  132.413  338.484   68.741  120.415
# 1973  0.000  2.969  0.234   3.925  14.978  304.484  696.024  256.932  183.206
# 1974  0.000  0.000  6.427  16.864  51.209  148.697  405.359  319.651  288.533
# 1975  0.333  0.585  0.000   0.061  30.651  359.369  474.143  404.372  400.001
# ...

# %%
fig, ax=plt.subplots(nrows=3, ncols=1, figsize=(12, 5), sharex=True, sharey=True)
ax[0].plot(df_lluvias.index, df_lluvias['Jan'], label="Precipitaciones de Enero")
ax[1].plot(df_lluvias.index, df_lluvias['Feb'], label="Precipitaciones de Febrero", color="C1")
ax[2].plot(df_lluvias.index, df_lluvias['Mar'], label="Precipitaciones de Marzo", color="C2")

ax[0].set_title("Precipitaciones en los 3 primeros meses del año")
ax[2].set_xlabel('Año')
ax[1].set_ylabel('Precipitación (mm.)')

ax[0].legend()
ax[1].legend()
ax[2].legend()

# %%
g=sns.FacetGrid(propinas, col="time", row="sex")
g.map(sns.scatterplot, "total_bill", "tip")

# %%
g1=sns.FacetGrid(propinas, col="time", hue="sex")
g1.map_dataframe(sns.scatterplot, x="total_bill", y="tip")
g1.add_legend()

# %%
import matplotlib as mpl
mpl.rcParams['axes.titleweight'] = 'bold'
mpl.rcParams['axes.titlelocation'] = 'left'
mpl.rcParams['axes.titlecolor'] = 'firebrick'
mpl.rcParams['axes.labelcolor'] = 'blue'
mpl.rcParams['axes.labelsize'] = '10'
mpl.rcParams['axes.labelweight'] = 'light'
mpl.rcParams['axes.linewidth'] = '1'
mpl.rcParams['grid.color'] = 'black'
mpl.rcParams['grid.linestyle'] = '-.'
mpl.rcParams['grid.linewidth'] = '2'

fig, ax = plt.subplots(figsize=(7, 4))
ax.scatter(df_lluvias['Aug'], df_lluvias['Sep'], c=df_lluvias.index)
ax.set_title('(Título rojo en negrita)')
ax.set_xlabel('(Etiqueta eje horiz.)')
ax.set_ylabel('(Etiqueta eje vert.)')
mpl.rcParams['axes.titleweight'] = 'bold'
mpl.rcParams['axes.titlelocation'] = 'left'
mpl.rcParams['axes.titlecolor'] = 'firebrick'
mpl.rcParams['axes.labelcolor'] = 'blue'
mpl.rcParams['axes.labelsize'] = '10'
mpl.rcParams['axes.labelweight'] = 'light'
mpl.rcParams['axes.linewidth'] = '1'
mpl.rcParams['grid.color'] = 'black'
mpl.rcParams['grid.linestyle'] = '-.'
mpl.rcParams['grid.linewidth'] = '2'

fig, ax = plt.subplots(figsize=(7, 4))
ax.scatter(df_lluvias['Aug'], df_lluvias['Sep'], c=df_lluvias.index)
ax.set_title('(Título rojo en negrita)')
ax.set_xlabel('(Etiqueta eje horiz.)')
ax.set_ylabel('(Etiqueta eje vert.)')
# Out:
# Text(0, 0.5, '(Etiqueta eje vert.)')

# %%
sns.histplot(data=pinguino, x="flipper_length_mm")
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.reset_orig()
sns.histplot(data=pinguino, x="flipper_length_mm")
plt.show()

# %%
df_ejercicio = sns.load_dataset('exercise')
df_ejercicio = df_ejercicio.drop('Unnamed: 0', axis='columns')
df_ejercicio.head()
# Out:
#    id     diet  pulse    time  kind
# 0   1  low fat     85   1 min  rest
# 1   1  low fat     85  15 min  rest
# 2   1  low fat     88  30 min  rest
# 3   2  low fat     90   1 min  rest
# 4   2  low fat     92  15 min  rest

# %%
df_30_min = df_ejercicio[df_ejercicio['time'] == '30 min']
df_30_min.head()
# Out:
#     id     diet  pulse    time  kind
# 2    1  low fat     88  30 min  rest
# 5    2  low fat     93  30 min  rest
# 8    3  low fat     94  30 min  rest
# 11   4  low fat     83  30 min  rest
# 14   5  low fat     91  30 min  rest

# %%
# Figure -level
ax = sns.displot(data=df_30_min, x='pulse', kind='kde', hue='kind', fill=True)
ax.set(xlabel='Frecuencia Cardíaca', ylabel='Densidad', title='Distribución  de las pulsaciones')
plt.show()

# %%
ax = sns.catplot(data=df_ejercicio, kind='violin', x='time', y='pulse', hue='diet', split=True)
ax.set(xlabel='Duración de ejercicio', ylabel='Frecuencia cardíaca', title='Categorización de la distribución de pulsaciones')
plt.show()
